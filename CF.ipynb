# %%
import pandas as pd
df = pd.read_excel('20210518_updated_CF_subjects_iontophoresis.xlsx', sheet_name = None)

# %%
subjects = set()
for key in df.keys():
    subjects.add(key[0:4])    
print(subjects)
# Out:
# {'ZF05', 'JF06', 'LF04', 'JM11', 'temp', 'AM18', 'AF08', 'KF24', 'CF22', 'KF13', 'SF14', 'TM10', 'CM16', 'AF20', 'EM12', 'JF19', 'LF03', 'JF23', 'CM02', 'JM07', 'KF17'}

# %%
subjects.remove("temp")
len(subjects)
# Out:
# 20

# %%
subjects
# Out:
# {'AF08',
#  'AF20',
#  'AM18',
#  'CF22',
#  'CM02',
#  'CM16',
#  'EM12',
#  'JF06',
#  'JF19',
#  'JF23',
#  'JM07',
#  'JM11',
#  'KF13',
#  'KF17',
#  'KF24',
#  'LF03',
#  'LF04',
#  'SF14',
#  'TM10',
#  'ZF05'}

# %%
list(df.keys())[0][0:3]  == list(df.keys())[1][0:3]
# Out:
# True

# %%
df["KF17_K1"]
# Out:
#            Date Subject ID  Age Gender Modulator       Genotype  \
# 0    2019-10-24    KF17_K1  NaN      F       Iva  F508del/G551D
# 1           NaT        NaN  NaN    NaN       NaN            NaN
# 2           NaT        NaN  NaN    NaN       NaN            NaN
# 3           NaT        NaN  NaN    NaN       NaN            NaN
# 4           NaT        NaN  NaN    NaN       NaN            NaN
# ...         ...        ...  ...    ...       ...            ...
# 2882        NaT        NaN  NaN    NaN       NaN            NaN
# 2883        NaT        NaN  NaN    NaN       NaN            NaN
# 2884        NaT        NaN  NaN    NaN       NaN            NaN
# 2885        NaT        NaN  NaN    NaN       NaN            NaN
# 2886        NaT        NaN  NaN    NaN       NaN            NaN
#
#      Modulator Start Date  Time (min)  Raw Sensor Cl (mM)  Peak Removal (mM)  \
# 0                 7 years    0.000000            0.150253                NaN
# 1                     NaN    0.016983            0.150125                NaN
# 2                     NaN    0.033483            0.150125                NaN
# 3                     NaN    0.050000            0.150125                NaN
# 4                     NaN    0.067000            0.150125                NaN
# ...                   ...         ...                 ...                ...
# 2882                  NaN   49.279992           46.921916          46.921916
# 2883                  NaN   49.299167           47.002090          47.002090
# 2884                  NaN   49.318342           47.062310          47.062310
# 2885                  NaN   49.337517           47.022155          47.022155
# 2886                  NaN   49.356692           47.162849          47.162849
#
#       ...  5-minute moving avg (mM).1  Unnamed: 25  Time (min).3   SR.1  \
# 0     ...                         NaN          NaN           0.0    NaN
# 1     ...                         NaN          NaN           2.0    NaN
# 2     ...                         NaN          NaN           4.0    NaN
# 3     ...                         NaN          NaN           6.0  0.133
# 4     ...                         NaN          NaN           8.0  0.299
# ...   ...                         ...          ...           ...    ...
# 2882  ...                         NaN          NaN           NaN    NaN
# 2883  ...                         NaN          NaN           NaN    NaN
# 2884  ...                         NaN          NaN           NaN    NaN
# 2885  ...                         NaN          NaN           NaN    NaN
# 2886  ...                         NaN          NaN           NaN    NaN
#
#       C_postdose_2min  C_postdose_peak_removal_2min  C_postdose_smooth_2min  \
# 0          197.774921                           NaN                     NaN
# 1          108.579620                           NaN                     NaN
# 2          103.863562                           NaN                     NaN
# 3          100.570996                     99.225843              100.316888
# 4           91.587986                     91.587986               96.772091
# ...               ...                           ...                     ...
# 2882              NaN                           NaN                     NaN
# 2883              NaN                           NaN                     NaN
# 2884              NaN                           NaN                     NaN
# 2885              NaN                           NaN                     NaN
# 2886              NaN                           NaN                     NaN
#
#       Unnamed: 31  Macroduct Concentration 3 (mM)  \
# 0             NaN                            63.0
# 1             NaN                             NaN
# 2             NaN                             NaN
# 3             NaN                             NaN
# 4             NaN                             NaN
# ...           ...                             ...
# 2882          NaN                             NaN
# 2883          NaN                             NaN
# 2884          NaN                             NaN
# 2885          NaN                             NaN
# 2886          NaN                             NaN
#
#       Macroduct Concentration 4 (mM)
# 0                               34.0
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ...                              ...
# 2882                             NaN
# 2883                             NaN
# 2884                             NaN
# 2885                             NaN
# 2886                             NaN
#
# [2887 rows x 34 columns]

# %%
df["KF17_K1"].iat[0,32]
# Out:
# 63.0

# %%
cf = pd.DataFrame()
# df_mac["Subject"] = df.keys()
cf = pd.DataFrame(columns = ["Subject",
                             "Age",
                             "Gender",
                             "Genotype",
                             "Modulator",
                            "Repeated trials",
                            "Macroduct Concentration 1 (mM)","Macroduct Concentration 2 (mM)",
                            "Macroduct Concentration 3 (mM)","Macroduct Concentration 4 (mM)",
                            "Mac 1 - Mac 2",
                            "Mac 3 - Mac 4"],
                     index = df.keys())

# %%
for key in df:
    cf.loc[key] = [key[0:4],
                   df[key].iat[0,2],
                   df[key].iat[0,3],
                   df[key].iat[0,5],
                   df[key].iat[0,4],
                    key[-2:],
                    df[key].iat[0,18],
                    df[key].iat[0,19],
                    df[key].iat[0,32],
                    df[key].iat[0,33],
                    df[key].iat[0,18] - df[key].iat[0,19],
                    df[key].iat[0,32] - df[key].iat[0,33]]
cf = cf.drop("template")

# %%
# get a set of genotype using for sorting
set(cf["Genotype"])
# Out:
# {'F508del / 3849+10kbC>T',
#  'F508del/2789+5GàA',
#  'F508del/3905insT',
#  'F508del/F508del',
#  'F508del/G542X',
#  'F508del/G551D',
#  'F508del/R1066C',
#  'F508del/W1282X',
#  'G551D/2622+1G>A',
#  'W1282X/2789+5G -> A'}

# %%
cf["Genotype"] = pd.Categorical(cf["Genotype"], ordered = True, 
                           categories = ["F508del/F508del", 
                                         "F508del/G551D", 
 'F508del / 3849+10kbC>T',
 'F508del/2789+5GàA',
 'F508del/3905insT',
 'F508del/G542X',
 'F508del/R1066C',
 'F508del/W1282X',
 'G551D/2622+1G>A',
 'W1282X/2789+5G -> A'])

# %%
cf_sorted = cf.sort_values(by = ["Genotype", "Subject"], ascending = True)

# %%
mapping = {item:i for i, item in enumerate(cf_sorted["Subject"].unique(),1)}
# insert column at a specific location
cf_sorted.insert(loc = 1, column = 'Subject Number', value = cf_sorted["Subject"].apply(lambda x: mapping[x]))
# cf_sorted["Subject Number"] = cf_sorted["Subject"].apply(lambda x: mapping[x])

# %%
mapping
# Out:
# {'CF22': 1,
#  'CM02': 2,
#  'EM12': 3,
#  'JF06': 4,
#  'JM07': 5,
#  'LF04': 6,
#  'SF14': 7,
#  'AM18': 8,
#  'KF13': 9,
#  'KF17': 10,
#  'AF08': 11,
#  'ZF05': 12,
#  'JM11': 13,
#  'AF20': 14,
#  'CM16': 15,
#  'TM10': 16,
#  'JF19': 17,
#  'JF23': 18,
#  'KF24': 19,
#  'LF03': 20}

# %%
#cf_sorted.set_index(cf_sorted["Subject"])
cf_sorted
# Out:
#         Subject  Subject Number   Age Gender                Genotype  \
# CF22_T1    CF22               1  28.0      F         F508del/F508del
# CM02_S1    CM02               2  39.0      M         F508del/F508del
# CM02_S2    CM02               2  39.0      M         F508del/F508del
# CM02_S3    CM02               2  39.0      M         F508del/F508del
# CM02_S4    CM02               2  39.0      M         F508del/F508del
# CM02_S5    CM02               2  39.0      M         F508del/F508del
# CM02_T1    CM02               2  40.0      M         F508del/F508del
# EM12_S1    EM12               3  32.0      M         F508del/F508del
# EM12_S2    EM12               3  32.0      M         F508del/F508del
# EM12_S3    EM12               3  32.0      M         F508del/F508del
# EM12_S4    EM12               3  32.0      M         F508del/F508del
# EM12_T1    EM12               3  32.0      M         F508del/F508del
# EM12_T2    EM12               3  32.0      M         F508del/F508del
# JF06_S1    JF06               4  36.0      F         F508del/F508del
# JF06_S2    JF06               4  36.0      F         F508del/F508del
# JF06_S3    JF06               4  37.0      F         F508del/F508del
# JF06_T1    JF06               4  37.0      F         F508del/F508del
# JM07_O1    JM07               5  21.0      M         F508del/F508del
# JM07_O2    JM07               5  21.0      M         F508del/F508del
# JM07_O3    JM07               5  21.0      M         F508del/F508del
# LF04_S1    LF04               6  25.0      F         F508del/F508del
# SF14_S1    SF14               7  27.0      F         F508del/F508del
# AM18_T1    AM18               8  27.0      M           F508del/G551D
# AM18_T2    AM18               8  27.0      M           F508del/G551D
# AM18_T3    AM18               8  27.0      M           F508del/G551D
# AM18_K1    AM18               8  27.0      M           F508del/G551D
# KF13_K1    KF13               9  46.0      F           F508del/G551D
# KF17_K1    KF17              10   NaN      F           F508del/G551D
# KF17_K2    KF17              10   NaN      F           F508del/G551D
# AF08_S1    AF08              11  19.0      F  F508del / 3849+10kbC>T
# AF08_S2    AF08              11  19.0      F  F508del / 3849+10kbC>T
# AF08_S3    AF08              11  19.0      F  F508del / 3849+10kbC>T
# ZF05_S1    ZF05              12   NaN      F       F508del/2789+5GàA
# ZF05_S2    ZF05              12   NaN      F       F508del/2789+5GàA
# JM11_1     JM11              13  31.0      M        F508del/3905insT
# JM11_2     JM11              13  31.0      M        F508del/3905insT
# AF20_1     AF20              14  22.0      F           F508del/G542X
# AF20_T1    AF20              14  22.0      F           F508del/G542X
# CM16_1     CM16              15  48.0      M           F508del/G542X
# TM10_1     TM10              16  23.0      M           F508del/G542X
# JF19_1     JF19              17  43.0      F          F508del/R1066C
# JF19_2     JF19              17  43.0      F          F508del/R1066C
# JF19_T1    JF19              17  43.0      F          F508del/R1066C
# JF23_T1    JF23              18  28.0      F          F508del/W1282X
# KF24_K1    KF24              19   NaN      F         G551D/2622+1G>A
# LF03_K1    LF03              20  40.0      F     W1282X/2789+5G -> A
# LF03_S1    LF03              20  40.0      F     W1282X/2789+5G -> A
#
#         Modulator Repeated trials Macroduct Concentration 1 (mM)  \
# CF22_T1       Tri              T1                           48.0
# CM02_S1   Tez/Iva              S1                           70.0
# CM02_S2   Tez/Iva              S2                             62
# CM02_S3   Tez/Iva              S3                           58.0
# CM02_S4   Tez/Iva              S4                             59
# CM02_S5   Tez/Iva              S5                           67.0
# CM02_T1   Tez/Iva              T1                           20.0
# EM12_S1   Tez/Iva              S1                           61.0
# EM12_S2   Tez/Iva              S2                           59.0
# EM12_S3   Tez/Iva              S3                           75.0
# EM12_S4   Tez/Iva              S4                           83.0
# EM12_T1   Tez/Iva              T1                           14.0
# EM12_T2   Tez/Iva              T2                           12.0
# JF06_S1   Tez/Iva              S1                           70.0
# JF06_S2   Tez/Iva              S2                             34
# JF06_S3   Tez/Iva              S3                           84.0
# JF06_T1   Tez/Iva              T1                           16.0
# JM07_O1   Lum/Iva              O1                           95.0
# JM07_O2   Lum/Iva              O2                           63.0
# JM07_O3   Lum/Iva              O3                           74.0
# LF04_S1   Tez/Iva              S1                          107.0
# SF14_S1   Tez/Iva              S1                             40
# AM18_T1       Tri              T1                           61.0
# AM18_T2       Tri              T2                           28.0
# AM18_T3       Tri              T3                           18.0
# AM18_K1       Iva              K1                           50.0
# KF13_K1       Iva              K1                           43.0
# KF17_K1       Iva              K1                           55.0
# KF17_K2       Iva              K2                           43.0
# AF08_S1   Tez/Iva              S1                           40.0
# AF08_S2   Tez/Iva              S2                           36.0
# AF08_S3   Tez/Iva              S3                           39.0
# ZF05_S1   Tez/Iva              S1                           91.0
# ZF05_S2   Tez/Iva              S2                           77.0
# JM11_1       None              _1                           99.0
# JM11_2       None              _2                          101.0
# AF20_1       None              _1                           95.0
# AF20_T1      None              T1                           51.0
# CM16_1       None              _1                           80.0
# TM10_1       None              _1                           86.0
# JF19_1       None              _1                           92.0
# JF19_2       None              _2                             92
# JF19_T1      None              T1                           58.0
# JF23_T1       Tri              T1                           29.0
# KF24_K1       Iva              K1                           58.0
# LF03_K1       Iva              K1                           89.0
# LF03_S1   Tez/Iva              S1                           88.0
#
#         Macroduct Concentration 2 (mM) Macroduct Concentration 3 (mM)  \
# CF22_T1                           48.0                           52.0
# CM02_S1                           73.0                           67.0
# CM02_S2                             91                           49.0
# CM02_S3                           79.0                           65.0
# CM02_S4                             85                             62
# CM02_S5                           73.0                           64.0
# CM02_T1                           21.0                           14.0
# EM12_S1                           74.0                           68.0
# EM12_S2                           67.0                           58.0
# EM12_S3                           82.0                           73.0
# EM12_S4                           88.0                           75.0
# EM12_T1                           15.0                           14.0
# EM12_T2                           13.0                           16.0
# JF06_S1                           66.0                           50.0
# JF06_S2                           85.0                           57.0
# JF06_S3                           87.0                           92.0
# JF06_T1                           15.0                           13.0
# JM07_O1                            106                           89.0
# JM07_O2                           83.0                             85
# JM07_O3                           67.0                           71.0
# LF04_S1                          114.0                           93.0
# SF14_S1                             46                           41.0
# AM18_T1                           37.0                           37.0
# AM18_T2                           19.0                           28.0
# AM18_T3                           22.0                           25.0
# AM18_K1                           35.0                           49.0
# KF13_K1                           30.0                           41.0
# KF17_K1                           30.0                           63.0
# KF17_K2                           25.0                           33.0
# AF08_S1                           32.0                           37.0
# AF08_S2                             41                             20
# AF08_S3                           37.0                           46.0
# ZF05_S1                           91.0                           85.0
# ZF05_S2                           86.0                           72.0
# JM11_1                           107.0                           99.0
# JM11_2                           110.0                           93.0
# AF20_1                           109.0                           89.0
# AF20_T1                           58.0                           52.0
# CM16_1                            81.0                            NaN
# TM10_1                           103.0                           99.0
# JF19_1                           101.0                           92.0
# JF19_2                              96                           96.0
# JF19_T1                             64                           36.0
# JF23_T1                           30.0                           21.0
# KF24_K1                           27.0                           48.0
# LF03_K1                           99.0                           90.0
# LF03_S1                             82                           80.0
#
#         Macroduct Concentration 4 (mM) Mac 1 - Mac 2 Mac 3 - Mac 4
# CF22_T1                           51.0           0.0           1.0
# CM02_S1                           74.0          -3.0          -7.0
# CM02_S2                          101.0           -29         -52.0
# CM02_S3                           65.0         -21.0           0.0
# CM02_S4                             72           -26           -10
# CM02_S5                           71.0          -6.0          -7.0
# CM02_T1                           21.0          -1.0          -7.0
# EM12_S1                           86.0         -13.0         -18.0
# EM12_S2                             78          -8.0         -20.0
# EM12_S3                           82.0          -7.0          -9.0
# EM12_S4                           85.0          -5.0         -10.0
# EM12_T1                           15.0          -1.0          -1.0
# EM12_T2                           16.0          -1.0           0.0
# JF06_S1                           45.0           4.0           5.0
# JF06_S2                           98.0         -51.0         -41.0
# JF06_S3                           84.0          -3.0           8.0
# JF06_T1                           12.0           1.0           1.0
# JM07_O1                          105.0         -11.0         -16.0
# JM07_O2                           92.0         -20.0          -7.0
# JM07_O3                           83.0           7.0         -12.0
# LF04_S1                          100.0          -7.0          -7.0
# SF14_S1                            NaN            -6           NaN
# AM18_T1                           28.0          24.0           9.0
# AM18_T2                           22.0           9.0           6.0
# AM18_T3                           29.0          -4.0          -4.0
# AM18_K1                           28.0          15.0          21.0
# KF13_K1                             23          13.0          18.0
# KF17_K1                           34.0          25.0          29.0
# KF17_K2                            NaN          18.0           NaN
# AF08_S1                           40.0           8.0          -3.0
# AF08_S2                            NaN          -5.0           NaN
# AF08_S3                             56           2.0         -10.0
# ZF05_S1                           96.0           0.0         -11.0
# ZF05_S2                           75.0          -9.0          -3.0
# JM11_1                           101.0          -8.0          -2.0
# JM11_2                           106.0          -9.0         -13.0
# AF20_1                           108.0         -14.0         -19.0
# AF20_T1                           56.0          -7.0          -4.0
# CM16_1                             NaN          -1.0           NaN
# TM10_1                           102.0         -17.0          -3.0
# JF19_1                            94.0          -9.0          -2.0
# JF19_2                             106            -4         -10.0
# JF19_T1                             26          -6.0          10.0
# JF23_T1                           22.0          -1.0          -1.0
# KF24_K1                           29.0          31.0          19.0
# LF03_K1                           98.0         -10.0          -8.0
# LF03_S1                           92.0           6.0         -12.0

# %%
print("Average age:", cf_sorted["Age"].mean())
print("SD:", cf_sorted["Age"].std())
# Out:
# Average age: 31.928571428571427
# SD: 8.104177956364978

# %%
cf_sorted.to_csv("cf_sorted.csv")

# %%
df['KF17_K1'].head()
# Out:
#         Date Subject ID  Age Gender Modulator       Genotype  \
# 0 2019-10-24    KF17_K1  NaN      F       Iva  F508del/G551D
# 1        NaT        NaN  NaN    NaN       NaN            NaN
# 2        NaT        NaN  NaN    NaN       NaN            NaN
# 3        NaT        NaN  NaN    NaN       NaN            NaN
# 4        NaT        NaN  NaN    NaN       NaN            NaN
#
#   Modulator Start Date  Time (min)  Raw Sensor Cl (mM)  Peak Removal (mM)  \
# 0              7 years    0.000000            0.150253                NaN
# 1                  NaN    0.016983            0.150125                NaN
# 2                  NaN    0.033483            0.150125                NaN
# 3                  NaN    0.050000            0.150125                NaN
# 4                  NaN    0.067000            0.150125                NaN
#
#    ...  5-minute moving avg (mM).1  Unnamed: 25  Time (min).3   SR.1  \
# 0  ...                         NaN          NaN           0.0    NaN
# 1  ...                         NaN          NaN           2.0    NaN
# 2  ...                         NaN          NaN           4.0    NaN
# 3  ...                         NaN          NaN           6.0  0.133
# 4  ...                         NaN          NaN           8.0  0.299
#
#    C_postdose_2min  C_postdose_peak_removal_2min  C_postdose_smooth_2min  \
# 0       197.774921                           NaN                     NaN
# 1       108.579620                           NaN                     NaN
# 2       103.863562                           NaN                     NaN
# 3       100.570996                     99.225843              100.316888
# 4        91.587986                     91.587986               96.772091
#
#    Unnamed: 31  Macroduct Concentration 3 (mM)  Macroduct Concentration 4 (mM)
# 0          NaN                            63.0                            34.0
# 1          NaN                             NaN                             NaN
# 2          NaN                             NaN                             NaN
# 3          NaN                             NaN                             NaN
# 4          NaN                             NaN                             NaN
#
# [5 rows x 34 columns]

# %%
cf.head()
# Out:
#         Subject   Age Gender       Genotype Modulator Repeated trials  \
# KF17_K1    KF17   NaN      F  F508del/G551D       Iva              K1
# KF17_K2    KF17   NaN      F  F508del/G551D       Iva              K2
# AM18_T1    AM18  27.0      M  F508del/G551D       Tri              T1
# AM18_T2    AM18  27.0      M  F508del/G551D       Tri              T2
# AM18_T3    AM18  27.0      M  F508del/G551D       Tri              T3
#
#         Macroduct Concentration 1 (mM) Macroduct Concentration 2 (mM)  \
# KF17_K1                           55.0                           30.0
# KF17_K2                           43.0                           25.0
# AM18_T1                           61.0                           37.0
# AM18_T2                           28.0                           19.0
# AM18_T3                           18.0                           22.0
#
#         Macroduct Concentration 3 (mM) Macroduct Concentration 4 (mM)  \
# KF17_K1                           63.0                           34.0
# KF17_K2                           33.0                            NaN
# AM18_T1                           37.0                           28.0
# AM18_T2                           28.0                           22.0
# AM18_T3                           25.0                           29.0
#
#         Mac 1 - Mac 2 Mac 3 - Mac 4
# KF17_K1          25.0          29.0
# KF17_K2          18.0           NaN
# AM18_T1          24.0           9.0
# AM18_T2           9.0           6.0
# AM18_T3          -4.0          -4.0

# %%
type(cf)
# Out:
# pandas.core.frame.DataFrame
